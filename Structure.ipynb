# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Full data as list of dictionaries
data = [
    {"Classification": "Pathogenic", "Mutation": "L755S", "Avg_RMSD": 0.286},
    {"Classification": "Pathogenic", "Mutation": "L755P", "Avg_RMSD": 0.240},
    {"Classification": "Pathogenic", "Mutation": "D769H", "Avg_RMSD": 0.255},
    {"Classification": "Pathogenic", "Mutation": "D769N", "Avg_RMSD": 0.242},
    {"Classification": "Pathogenic", "Mutation": "D769Y", "Avg_RMSD": 0.258},
    {"Classification": "Pathogenic", "Mutation": "V842L", "Avg_RMSD": 0.270},
    {"Classification": "Pathogenic", "Mutation": "L869R", "Avg_RMSD": 0.288},
    {"Classification": "Pathogenic", "Mutation": "L869Q", "Avg_RMSD": 0.296},
    {"Classification": "Pathogenic", "Mutation": "L869P", "Avg_RMSD": 0.293},
    {"Classification": "Pathogenic", "Mutation": "E914K", "Avg_RMSD": 0.260},
    {"Classification": "Pathogenic", "Mutation": "E914Q", "Avg_RMSD": 0.286},
    {"Classification": "VUS", "Mutation": "A848S", "Avg_RMSD": 0.283},
    {"Classification": "VUS", "Mutation": "A848T", "Avg_RMSD": 0.260},
    {"Classification": "VUS", "Mutation": "D863E", "Avg_RMSD": 0.258},
    {"Classification": "VUS", "Mutation": "D924H", "Avg_RMSD": 0.289},
    {"Classification": "VUS", "Mutation": "D924Y", "Avg_RMSD": 0.282},
    {"Classification": "VUS", "Mutation": "E766K", "Avg_RMSD": 0.263},
    {"Classification": "VUS", "Mutation": "E892Q", "Avg_RMSD": 0.244},
    {"Classification": "VUS", "Mutation": "E892K", "Avg_RMSD": 0.279},
    {"Classification": "VUS", "Mutation": "G776D", "Avg_RMSD": 0.292},
    {"Classification": "VUS", "Mutation": "I989F", "Avg_RMSD": 0.244},
    {"Classification": "VUS", "Mutation": "R811W", "Avg_RMSD": 0.256},
    {"Classification": "VUS", "Mutation": "R816P", "Avg_RMSD": 0.287},
    {"Classification": "VUS", "Mutation": "R897P", "Avg_RMSD": 0.261},
    {"Classification": "VUS", "Mutation": "R897Q", "Avg_RMSD": 0.319},
    {"Classification": "VUS", "Mutation": "R897W", "Avg_RMSD": 0.231},
    {"Classification": "VUS", "Mutation": "R978C", "Avg_RMSD": 0.255},
    {"Classification": "VUS", "Mutation": "T948I", "Avg_RMSD": 0.280},
    {"Classification": "VUS", "Mutation": "W913L", "Avg_RMSD": 0.239},
    {"Classification": "VUS", "Mutation": "R970P", "Avg_RMSD": 0.249},
    {"Classification": "VUS", "Mutation": "K831M", "Avg_RMSD": 0.254},
    {"Classification": "VUS", "Mutation": "W913S", "Avg_RMSD": 0.288},
]

# Create DataFrame
df = pd.DataFrame(data)

# Assign color based on classification
color_map = {"Pathogenic": "orange", "VUS": "blue"}
df["Color"] = df["Classification"].map(color_map)

# Plot
plt.figure(figsize=(16, 6))
bars = plt.bar(df["Mutation"], df["Avg_RMSD"], color=df["Color"])

# Add labels
plt.xlabel("Mutation")
plt.ylabel("Average RMSD")
plt.title("Average RMSD by Mutation - Pathogenic vs VUS")
plt.xticks(rotation=90)

# Add legend
legend_elements = [
    Patch(facecolor='orange', label='Pathogenic'),
    Patch(facecolor='blue', label='VUS')
]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Full data with RMSF values
data = [
    {"Classification": "Pathogenic", "Mutation": "L755S", "Avg_RMSF": 0.136},
    {"Classification": "Pathogenic", "Mutation": "L755P", "Avg_RMSF": 0.131},
    {"Classification": "Pathogenic", "Mutation": "D769H", "Avg_RMSF": 0.118},
    {"Classification": "Pathogenic", "Mutation": "D769N", "Avg_RMSF": 0.120},
    {"Classification": "Pathogenic", "Mutation": "D769Y", "Avg_RMSF": 0.130},
    {"Classification": "Pathogenic", "Mutation": "V842L", "Avg_RMSF": 0.127},
    {"Classification": "Pathogenic", "Mutation": "L869R", "Avg_RMSF": 0.129},
    {"Classification": "Pathogenic", "Mutation": "L869Q", "Avg_RMSF": 0.110},
    {"Classification": "Pathogenic", "Mutation": "L869P", "Avg_RMSF": 0.127},
    {"Classification": "Pathogenic", "Mutation": "E914K", "Avg_RMSF": 0.120},
    {"Classification": "Pathogenic", "Mutation": "E914Q", "Avg_RMSF": 0.125},
    {"Classification": "VUS", "Mutation": "A848S", "Avg_RMSF": 0.135},
    {"Classification": "VUS", "Mutation": "A848T", "Avg_RMSF": 0.111},
    {"Classification": "VUS", "Mutation": "D863E", "Avg_RMSF": 0.125},
    {"Classification": "VUS", "Mutation": "D924H", "Avg_RMSF": 0.147},
    {"Classification": "VUS", "Mutation": "D924Y", "Avg_RMSF": 0.133},
    {"Classification": "VUS", "Mutation": "E766K", "Avg_RMSF": 0.114},
    {"Classification": "VUS", "Mutation": "E892Q", "Avg_RMSF": 0.115},
    {"Classification": "VUS", "Mutation": "E892K", "Avg_RMSF": 0.132},
    {"Classification": "VUS", "Mutation": "G776D", "Avg_RMSF": 0.135},
    {"Classification": "VUS", "Mutation": "I989F", "Avg_RMSF": 0.125},
    {"Classification": "VUS", "Mutation": "R811W", "Avg_RMSF": 0.097},
    {"Classification": "VUS", "Mutation": "R816P", "Avg_RMSF": 0.137},
    {"Classification": "VUS", "Mutation": "R897P", "Avg_RMSF": 0.115},
    {"Classification": "VUS", "Mutation": "R897Q", "Avg_RMSF": 0.116},
    {"Classification": "VUS", "Mutation": "R897W", "Avg_RMSF": 0.113},
    {"Classification": "VUS", "Mutation": "R978C", "Avg_RMSF": 0.119},
    {"Classification": "VUS", "Mutation": "T948I", "Avg_RMSF": 0.119},
    {"Classification": "VUS", "Mutation": "W913L", "Avg_RMSF": 0.140},
    {"Classification": "VUS", "Mutation": "R970P", "Avg_RMSF": 0.117},
    {"Classification": "VUS", "Mutation": "K831M", "Avg_RMSF": 0.115},
    {"Classification": "VUS", "Mutation": "W913S", "Avg_RMSF": 0.140},
]

# Create DataFrame
df = pd.DataFrame(data)

# Assign color based on classification
color_map = {"Pathogenic": "orange", "VUS": "blue"}
df["Color"] = df["Classification"].map(color_map)

# Plot
plt.figure(figsize=(16, 6))
bars = plt.bar(df["Mutation"], df["Avg_RMSF"], color=df["Color"])

# Add labels
plt.xlabel("Mutation")
plt.ylabel("Average RMSF")
plt.title("Average RMSF by Mutation - Pathogenic vs VUS")
plt.xticks(rotation=90)

# Add legend
legend_elements = [
    Patch(facecolor='orange', label='Pathogenic'),
    Patch(facecolor='blue', label='VUS')
]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Full data with Avg_Rg values
data = [
    {"Classification": "Pathogenic", "Mutation": "L755S", "Avg_Rg": 2.019},
    {"Classification": "Pathogenic", "Mutation": "L755P", "Avg_Rg": 2.005},
    {"Classification": "Pathogenic", "Mutation": "D769H", "Avg_Rg": 1.994},
    {"Classification": "Pathogenic", "Mutation": "D769N", "Avg_Rg": 1.986},
    {"Classification": "Pathogenic", "Mutation": "D769Y", "Avg_Rg": 2.008},
    {"Classification": "Pathogenic", "Mutation": "V842L", "Avg_Rg": 2.019},
    {"Classification": "Pathogenic", "Mutation": "L869R", "Avg_Rg": 1.989},
    {"Classification": "Pathogenic", "Mutation": "L869Q", "Avg_Rg": 1.992},
    {"Classification": "Pathogenic", "Mutation": "L869P", "Avg_Rg": 2.019},
    {"Classification": "Pathogenic", "Mutation": "E914K", "Avg_Rg": 1.989},
    {"Classification": "Pathogenic", "Mutation": "E914Q", "Avg_Rg": 1.973},
    {"Classification": "VUS", "Mutation": "A848S", "Avg_Rg": 2.004},
    {"Classification": "VUS", "Mutation": "A848T", "Avg_Rg": 1.998},
    {"Classification": "VUS", "Mutation": "D863E", "Avg_Rg": 1.979},
    {"Classification": "VUS", "Mutation": "D924H", "Avg_Rg": 2.015},
    {"Classification": "VUS", "Mutation": "D924Y", "Avg_Rg": 2.004},
    {"Classification": "VUS", "Mutation": "E766K", "Avg_Rg": 1.970},
    {"Classification": "VUS", "Mutation": "E892Q", "Avg_Rg": 1.984},
    {"Classification": "VUS", "Mutation": "E892K", "Avg_Rg": 2.016},
    {"Classification": "VUS", "Mutation": "G776D", "Avg_Rg": 2.007},
    {"Classification": "VUS", "Mutation": "I989F", "Avg_Rg": 2.004},
    {"Classification": "VUS", "Mutation": "R811W", "Avg_Rg": 2.010},
    {"Classification": "VUS", "Mutation": "R816P", "Avg_Rg": 2.022},
    {"Classification": "VUS", "Mutation": "R897P", "Avg_Rg": 1.995},
    {"Classification": "VUS", "Mutation": "R897Q", "Avg_Rg": 2.016},
    {"Classification": "VUS", "Mutation": "R897W", "Avg_Rg": 2.002},
    {"Classification": "VUS", "Mutation": "R978C", "Avg_Rg": 2.001},
    {"Classification": "VUS", "Mutation": "T948I", "Avg_Rg": 2.017},
    {"Classification": "VUS", "Mutation": "W913L", "Avg_Rg": 1.985},
    {"Classification": "VUS", "Mutation": "R970P", "Avg_Rg": 1.998},
    {"Classification": "VUS", "Mutation": "K831M", "Avg_Rg": 2.018},
    {"Classification": "VUS", "Mutation": "W913S", "Avg_Rg": 2.015},
]

# Create DataFrame
df = pd.DataFrame(data)

# Assign color based on classification
color_map = {"Pathogenic": "orange", "VUS": "blue"}
df["Color"] = df["Classification"].map(color_map)

# Plot
plt.figure(figsize=(16, 6))
bars = plt.bar(df["Mutation"], df["Avg_Rg"], color=df["Color"])

# Add labels
plt.xlabel("Mutation")
plt.ylabel("Average Radius of Gyration (Rg)")
plt.title("Average Rg by Mutation - Pathogenic vs VUS")
plt.xticks(rotation=90)

# Add legend
legend_elements = [
    Patch(facecolor='orange', label='Pathogenic'),
    Patch(facecolor='blue', label='VUS')
]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Full data with Avg_SASA values
data = [
    {"Classification": "Pathogenic", "Mutation": "L755S", "Avg_SASA": 152.113},
    {"Classification": "Pathogenic", "Mutation": "L755P", "Avg_SASA": 152.933},
    {"Classification": "Pathogenic", "Mutation": "D769H", "Avg_SASA": 151.809},
    {"Classification": "Pathogenic", "Mutation": "D769N", "Avg_SASA": 149.126},
    {"Classification": "Pathogenic", "Mutation": "D769Y", "Avg_SASA": 153.513},
    {"Classification": "Pathogenic", "Mutation": "V842L", "Avg_SASA": 153.819},
    {"Classification": "Pathogenic", "Mutation": "L869R", "Avg_SASA": 153.215},
    {"Classification": "Pathogenic", "Mutation": "L869Q", "Avg_SASA": 151.465},
    {"Classification": "Pathogenic", "Mutation": "L869P", "Avg_SASA": 154.097},
    {"Classification": "Pathogenic", "Mutation": "E914K", "Avg_SASA": 150.152},
    {"Classification": "Pathogenic", "Mutation": "E914Q", "Avg_SASA": 147.039},
    {"Classification": "VUS", "Mutation": "A848S", "Avg_SASA": 153.170},
    {"Classification": "VUS", "Mutation": "A848T", "Avg_SASA": 150.356},
    {"Classification": "VUS", "Mutation": "D863E", "Avg_SASA": 149.542},
    {"Classification": "VUS", "Mutation": "D924H", "Avg_SASA": 153.825},
    {"Classification": "VUS", "Mutation": "D924Y", "Avg_SASA": 155.271},
    {"Classification": "VUS", "Mutation": "E766K", "Avg_SASA": 149.516},
    {"Classification": "VUS", "Mutation": "E892Q", "Avg_SASA": 150.797},
    {"Classification": "VUS", "Mutation": "E892K", "Avg_SASA": 153.582},
    {"Classification": "VUS", "Mutation": "G776D", "Avg_SASA": 153.763},
    {"Classification": "VUS", "Mutation": "I989F", "Avg_SASA": 151.683},
    {"Classification": "VUS", "Mutation": "R811W", "Avg_SASA": 148.572},
    {"Classification": "VUS", "Mutation": "R816P", "Avg_SASA": 153.126},
    {"Classification": "VUS", "Mutation": "R897P", "Avg_SASA": 151.280},
    {"Classification": "VUS", "Mutation": "R897Q", "Avg_SASA": 152.140},
    {"Classification": "VUS", "Mutation": "R897W", "Avg_SASA": 150.593},
    {"Classification": "VUS", "Mutation": "R978C", "Avg_SASA": 153.628},
    {"Classification": "VUS", "Mutation": "T948I", "Avg_SASA": 152.932},
    {"Classification": "VUS", "Mutation": "W913L", "Avg_SASA": 151.687},
    {"Classification": "VUS", "Mutation": "R970P", "Avg_SASA": 151.774},
    {"Classification": "VUS", "Mutation": "K831M", "Avg_SASA": 153.574},
    {"Classification": "VUS", "Mutation": "W913S", "Avg_SASA": 151.967},
]

# Create DataFrame
df = pd.DataFrame(data)

# Assign color based on classification
color_map = {"Pathogenic": "orange", "VUS": "blue"}
df["Color"] = df["Classification"].map(color_map)

# Plot
plt.figure(figsize=(16, 6))
bars = plt.bar(df["Mutation"], df["Avg_SASA"], color=df["Color"])

# Add labels
plt.xlabel("Mutation")
plt.ylabel("Average SASA")
plt.title("Average SASA by Mutation - Pathogenic vs VUS")
plt.xticks(rotation=90)

# Add legend
legend_elements = [
    Patch(facecolor='orange', label='Pathogenic'),
    Patch(facecolor='blue', label='VUS')
]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Full data with Avg_Hydrogen Bonds values
data = [
    {"Classification": "Pathogenic", "Mutation": "L755S", "Avg_HBonds": 199.401},
    {"Classification": "Pathogenic", "Mutation": "L755P", "Avg_HBonds": 201.085},
    {"Classification": "Pathogenic", "Mutation": "D769H", "Avg_HBonds": 204.904},
    {"Classification": "Pathogenic", "Mutation": "D769N", "Avg_HBonds": 205.068},
    {"Classification": "Pathogenic", "Mutation": "D769Y", "Avg_HBonds": 204.992},
    {"Classification": "Pathogenic", "Mutation": "V842L", "Avg_HBonds": 203.066},
    {"Classification": "Pathogenic", "Mutation": "L869R", "Avg_HBonds": 201.948},
    {"Classification": "Pathogenic", "Mutation": "L869Q", "Avg_HBonds": 209.147},
    {"Classification": "Pathogenic", "Mutation": "L869P", "Avg_HBonds": 202.442},
    {"Classification": "Pathogenic", "Mutation": "E914K", "Avg_HBonds": 209.416},
    {"Classification": "Pathogenic", "Mutation": "E914Q", "Avg_HBonds": 206.367},
    {"Classification": "VUS", "Mutation": "A848S", "Avg_HBonds": 199.774},
    {"Classification": "VUS", "Mutation": "A848T", "Avg_HBonds": 201.292},
    {"Classification": "VUS", "Mutation": "D863E", "Avg_HBonds": 201.590},
    {"Classification": "VUS", "Mutation": "D924H", "Avg_HBonds": 206.523},
    {"Classification": "VUS", "Mutation": "D924Y", "Avg_HBonds": 201.195},
    {"Classification": "VUS", "Mutation": "E766K", "Avg_HBonds": 207.147},
    {"Classification": "VUS", "Mutation": "E892Q", "Avg_HBonds": 198.379},
    {"Classification": "VUS", "Mutation": "E892K", "Avg_HBonds": 199.105},
    {"Classification": "VUS", "Mutation": "G776D", "Avg_HBonds": 202.373},
    {"Classification": "VUS", "Mutation": "I989F", "Avg_HBonds": 202.493},
    {"Classification": "VUS", "Mutation": "R811W", "Avg_HBonds": 197.889},
    {"Classification": "VUS", "Mutation": "R816P", "Avg_HBonds": 197.734},
    {"Classification": "VUS", "Mutation": "R897P", "Avg_HBonds": 204.941},
    {"Classification": "VUS", "Mutation": "R897Q", "Avg_HBonds": 202.201},
    {"Classification": "VUS", "Mutation": "R897W", "Avg_HBonds": 202.333},
    {"Classification": "VUS", "Mutation": "R978C", "Avg_HBonds": 200.413},
    {"Classification": "VUS", "Mutation": "T948I", "Avg_HBonds": 199.943},
    {"Classification": "VUS", "Mutation": "W913L", "Avg_HBonds": 198.673},
    {"Classification": "VUS", "Mutation": "R970P", "Avg_HBonds": 200.130},
    {"Classification": "VUS", "Mutation": "K831M", "Avg_HBonds": 202.678},
    {"Classification": "VUS", "Mutation": "W913S", "Avg_HBonds": 201.801},
]

# Create DataFrame
df = pd.DataFrame(data)

# Assign color based on classification
color_map = {"Pathogenic": "orange", "VUS": "blue"}
df["Color"] = df["Classification"].map(color_map)

# Plot
plt.figure(figsize=(16, 6))
bars = plt.bar(df["Mutation"], df["Avg_HBonds"], color=df["Color"])

# Add labels
plt.xlabel("Mutation")
plt.ylabel("Average Hydrogen Bonds")
plt.title("Average Hydrogen Bonds by Mutation - Pathogenic vs VUS")
plt.xticks(rotation=90)

# Add legend
legend_elements = [
    Patch(facecolor='orange', label='Pathogenic'),
    Patch(facecolor='blue', label='VUS')
]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Data for Gibbs free energy (kJ/mol)
data = [
    {"Classification": "Pathogenic", "Mutation": "L755S", "Gibbs": 14.4},
    {"Classification": "Pathogenic", "Mutation": "L755P", "Gibbs": 14.6},
    {"Classification": "Pathogenic", "Mutation": "D769H", "Gibbs": 14.2},
    {"Classification": "Pathogenic", "Mutation": "D769N", "Gibbs": 14.0},
    {"Classification": "Pathogenic", "Mutation": "D769Y", "Gibbs": 14.2},
    {"Classification": "Pathogenic", "Mutation": "V842L", "Gibbs": 15.1},
    {"Classification": "Pathogenic", "Mutation": "L869R", "Gibbs": 14.8},
    {"Classification": "Pathogenic", "Mutation": "L869Q", "Gibbs": 15.3},
    {"Classification": "Pathogenic", "Mutation": "L869P", "Gibbs": 14.1},
    {"Classification": "Pathogenic", "Mutation": "E914K", "Gibbs": 15.4},
    {"Classification": "Pathogenic", "Mutation": "E914Q", "Gibbs": 19.4},
    {"Classification": "VUS", "Mutation": "A848S", "Gibbs": 14.1},
    {"Classification": "VUS", "Mutation": "A848T", "Gibbs": 15.4},
    {"Classification": "VUS", "Mutation": "D863E", "Gibbs": 14.4},
    {"Classification": "VUS", "Mutation": "D924H", "Gibbs": 14.4},
    {"Classification": "VUS", "Mutation": "D924Y", "Gibbs": 15.0},
    {"Classification": "VUS", "Mutation": "E766K", "Gibbs": 16.5},
    {"Classification": "VUS", "Mutation": "E892Q", "Gibbs": 16.2},
    {"Classification": "VUS", "Mutation": "E892K", "Gibbs": 14.8},
    {"Classification": "VUS", "Mutation": "G776D", "Gibbs": 13.6},
    {"Classification": "VUS", "Mutation": "I989F", "Gibbs": 14.3},
    {"Classification": "VUS", "Mutation": "R811W", "Gibbs": 13.6},
    {"Classification": "VUS", "Mutation": "R816P", "Gibbs": 15.3},
    {"Classification": "VUS", "Mutation": "R897P", "Gibbs": 14.6},
    {"Classification": "VUS", "Mutation": "R897Q", "Gibbs": 15.7},
    {"Classification": "VUS", "Mutation": "R897W", "Gibbs": 13.8},
    {"Classification": "VUS", "Mutation": "R978C", "Gibbs": 13.6},
    {"Classification": "VUS", "Mutation": "T948I", "Gibbs": 13.4},
    {"Classification": "VUS", "Mutation": "W913L", "Gibbs": 15.0},
    {"Classification": "VUS", "Mutation": "R970P", "Gibbs": 14.7},
    {"Classification": "VUS", "Mutation": "K831M", "Gibbs": 14.4},
    {"Classification": "VUS", "Mutation": "W913S", "Gibbs": 16.3},
]

# Create DataFrame
df = pd.DataFrame(data)

# Assign color based on classification
color_map = {"Pathogenic": "orange", "VUS": "blue"}
df["Color"] = df["Classification"].map(color_map)

# Plot
plt.figure(figsize=(16, 6))
plt.bar(df["Mutation"], df["Gibbs"], color=df["Color"])

# Labels
plt.xlabel("Mutation")
plt.ylabel("Gibbs Free Energy (kJ/mol)")
plt.title("Gibbs Free Energy by Mutation - Pathogenic vs VUS")
plt.xticks(rotation=90)

# Legend
legend_elements = [
    Patch(facecolor='orange', label='Pathogenic'),
    Patch(facecolor='blue', label='VUS')
]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()
